# %%
import pandas as pd

# %%
online_retail_store_df = pd.read_excel('C:/Users/91706/Downloads/online+retail+ii/online_retail_II.xlsx')

# %%
online_retail_store_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
online_retail_store_df[online_retail_store_df['InvoiceDate']=='2010-12-01 08:26:00']
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 502938  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 502939  536365     71053                  WHITE METAL LANTERN         6
# 502940  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 502941  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 502942  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 502943  536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 502944  536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
#
#                InvoiceDate  Price  Customer ID         Country
# 502938 2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 502939 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 502940 2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 502941 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 502942 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# ...

# %%
online_retail_store_df.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
online_retail_store_df[online_retail_store_df['Quantity']<0]
# Out:
#         Invoice StockCode                    Description  Quantity  \
# 178     C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896             POTTING SHED TWINE        -6
# 182     C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                            ...       ...
# 525231   538159     21324                            NaN       -18
# 525232   538158     20892                            NaN       -32
# 525234   538161    46000S                   Dotcom sales      -100
# 525235   538162    46000M                   Dotcom sales      -100
# 525282  C538164    35004B    SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %%
grouped_df = online_retail_store_df.groupby('Invoice')

# %%
grouped_df['Invoice'].apply(
    lambda x: x.astype(str).str.startswith(('c', 'C'), na=False).sum()
)
# Out:
# Invoice
# 489434     0
# 489435     0
# 489436     0
# 489437     0
# 489438     0
#           ..
# C538121    1
# C538122    1
# C538123    3
# C538124    3
# C538164    1
# Name: Invoice, Length: 28816, dtype: int64

# %%
grouped_df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 grouped_df.columns
#
# File c:\Users\91706\Anaconda\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'
